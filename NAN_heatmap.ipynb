# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.patches import Patch

# %%
df = pd.read_csv('clean_dataset.csv')
df.head()
# Out:
#    X  comp_bed_9  mat_dep  mat_age  weight_16   height_16     iq  \
# 0  1         NaN      3.0     30.0  59.294132  181.602831  107.0
# 1  2         NaN      9.0     26.0        NaN         NaN   85.0
# 2  3         NaN      3.0     24.0        NaN         NaN    NaN
# 3  4         0.0      NaN     22.0  49.812426  160.224186    NaN
# 4  5         0.0      8.0     31.0  62.270030  191.703227  132.0
#
#    comp_noint_bed_16  comp_int_bed_16  talk_phon_wend  ...  dep_score  \
# 0                NaN              NaN             1.0  ...        0.0
# 1                NaN              NaN             NaN  ...        NaN
# 2                NaN              NaN             NaN  ...        NaN
# 3                NaN              NaN             NaN  ...        NaN
# 4                1.0              NaN             0.0  ...        NaN
#
#    comp_house  tv_bed_16  creat_14  comp_games  fam_tv_eve  fam_tv_aft  \
# 0         1.0        1.0       1.0         0.0         1.0         0.0
# ...

# %%
# replace NA with NAN
missing_values_matrix = df.replace('NA', np.nan)
# change sex values to integers
missing_values_matrix['sex'] = missing_values_matrix['sex'].replace('Female', 1)
missing_values_matrix['sex'] = missing_values_matrix['sex'].replace('Male', 2)
# get boolean values
missing_values_matrix = missing_values_matrix.isna()
missing_values_matrix.head()
# Out:
#        X  comp_bed_9  mat_dep  mat_age  weight_16  height_16     iq  \
# 0  False        True    False    False      False      False  False
# 1  False        True    False    False       True       True  False
# 2  False        True    False    False       True       True   True
# 3  False       False     True    False      False      False   True
# 4  False       False    False    False      False      False  False
#
#    comp_noint_bed_16  comp_int_bed_16  talk_phon_wend  ...  dep_score  \
# 0               True             True           False  ...      False
# 1               True             True            True  ...       True
# 2               True             True            True  ...       True
# 3               True             True            True  ...       True
# 4              False             True           False  ...       True
#
#    comp_house  tv_bed_16  creat_14  comp_games  fam_tv_eve  fam_tv_aft  \
# ...

# %%
missing_values_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13734 entries, 0 to 13733
# Data columns (total 83 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  13734 non-null  bool
#  1   comp_bed_9         13734 non-null  bool
#  2   mat_dep            13734 non-null  bool
#  3   mat_age            13734 non-null  bool
#  4   weight_16          13734 non-null  bool
#  5   height_16          13734 non-null  bool
#  6   iq                 13734 non-null  bool
#  7   comp_noint_bed_16  13734 non-null  bool
#  8   comp_int_bed_16    13734 non-null  bool
#  9   talk_phon_wend     13734 non-null  bool
#  10  text_wend          13734 non-null  bool
#  11  talk_mob_wend      13734 non-null  bool
#  12  comp_wend          13734 non-null  bool
#  13  musi_wend          13734 non-null  bool
#  14  read_wend          13734 non-null  bool
#  15  work_wend          13734 non-null  bool
# ...

# %%
# Set up the plot size and style
plt.figure(figsize=(26, 8))
sns.set(style='white')

# Create the heatmap
sns.heatmap(missing_values_matrix, cmap='viridis', cbar=False, yticklabels=False)

# Customize the plot
plt.title('Missing Values Heatmap', fontsize=18)
plt.xlabel('Columns', fontsize=14)
plt.ylabel('Rows', fontsize=14)

# Create custom legend
legend_elements = [Patch(facecolor='purple', edgecolor='purple', label='Non-missing Value'),
                   Patch(facecolor='yellow', edgecolor='yellow', label='NA')]

plt.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.8, 1.11), ncol=3, fontsize=12, title='Value Status', title_fontsize=14)

# Show the plot
plt.show()
